# %% [markdown]
# # PA2: Personenerkennung auf dem PYNQ-Z1 — Custom-CNN + QAT + Pruning + hls4ml
#
# **Modell:** Custom-CNN (5× MaxPool, kein DepthwiseConv2D, kein GlobalAveragePooling)
# **Optimierung:** QAT mit QKeras (6-Bit) + Pruning (50 % Sparsity, PolynomialDecay)
# **Zielplattform:** PYNQ-Z1 (Zynq-7020, 220 DSPs)
# **Referenz STM32:** MobileNetV2 TFLite-int8, 303 ms (Bachelorarbeit, Abb. 51 & 52)
#
# **Warum Custom-CNN statt MobileNetV2?**
# hls4ml verarbeitet `GlobalAveragePooling2D + io_stream` nicht korrekt (alle Outputs identisch). Wang et al. [FPL 2019] benötigen 4 RTL-Techniken auf einem ZCU102 (2520 DSPs). Das Custom-CNN umgeht alle Kompatibilitätsprobleme vollständig.
#
# **Warum 5× MaxPool?**
# 4× MaxPool → Flatten 6×6×64 = 2304 Inputs → Dense-Schicht zu groß für Vivado HLS Unrolling (XFORM 203-504). 5× MaxPool → 3×3×64 = 576 Inputs → synthetisierbar.
#
# **Ablauf:**
# 1. Umgebung · 2. Datensatz · 3. Baseline-CNN · 4. Baseline-Training · 5. Pruning · 6. QKeras-Modell · 7. QAT+Pruning Training · 8. Vergleich · 9. hls4ml-Konvertierung · 10. CPU-Emulation · 11. Plattformvergleich · 12. Synthesebericht · 13. Synthese · 14. Deployment

# %% [markdown]
# ## 1. Umgebung einrichten

# %% [markdown]
# # Vitis HLS 2022.2 —
# import os
# os.environ['PATH'] = '/tools/Xilinx/Vitis_HLS/2022.2/bin:' + os.environ['PATH']
# !which vitis_hls

# %%
from tensorflow.keras.models import load_model
from qkeras.utils import _add_supported_quantized_objects

co = {}
_add_supported_quantized_objects(co)

import os

os.environ['PATH'] = os.environ['XILINX_VIVADO'] + '/bin:' + os.environ['PATH']
# Out:
# 2026-07-02 19:22:49.896153: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
#!pip uninstall hls4ml==1.1.0
#!pip install hls4ml==1.1.0
# !pip install keras

#print(f'hls4ml     : {hls4ml.__version__}')

# %%
import os, math, re, shutil, subprocess, time, glob, random
import keras
import numpy as np
import tensorflow as tf
import hls4ml
import pprint
import matplotlib; matplotlib.use('Agg')
import matplotlib.pyplot as plt
from pathlib import Path
from sklearn.metrics import confusion_matrix, classification_report

# QKeras
from qkeras import QActivation, QDense, QConv2DBatchnorm
from qkeras.utils import _add_supported_quantized_objects

# Pruning
import tensorflow_model_optimization as tfmot
from tensorflow_model_optimization.sparsity import keras as sparsity
from tensorflow_model_optimization.python.core.sparsity.keras import pruning_callbacks
from tensorflow_model_optimization.sparsity.keras import strip_pruning
from tensorflow_model_optimization.python.core.sparsity.keras import pruning_wrapper

from tensorflow.keras.layers import (Input, Conv2D, BatchNormalization,
    Activation, MaxPooling2D, Flatten, Dense)
from tensorflow.keras.regularizers import l1
from tensorflow.keras.models import Model

co = {}; _add_supported_quantized_objects(co)
co['PruneLowMagnitude'] = pruning_wrapper.PruneLowMagnitude

random.seed(42); np.random.seed(42); tf.random.set_seed(42)

print(f'TensorFlow : {tf.__version__}')
print(f'hls4ml     : {hls4ml.__version__}')
# Out:
# TensorFlow : 2.14.0
# hls4ml     : 1.1.0

# %%
# train_model.py
import numpy as np
from qkeras import QActivation, QDense, QConv2DBatchnorm

# ── Load and resize to 8x8 ────────────────────────────────────────────────────
mnist = keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Resize from 28x28 to 8x8
import tensorflow as tf
x_train = tf.image.resize(x_train[..., np.newaxis], [8, 8]).numpy() / 255.0
x_test  = tf.image.resize(x_test[..., np.newaxis],  [8, 8]).numpy() / 255.0

# Sur le PC d'entraînement
np.save('x_test_8x8.npy', x_test[:500].astype(np.float32))
np.save('y_test.npy', y_test[:500])

print("Input shape:", x_train.shape)  # should be (60000, 8, 8, 1)

# ── Small CNN for 8x8 input ───────────────────────────────────────────────────
input_shape             = (8, 8, 1)
n_classes               = 10
filters_per_conv_layer  = [4, 8]

x = x_in = Input(shape=input_shape, name='img_input')

for i, f in enumerate(filters_per_conv_layer):
    x = QConv2DBatchnorm(
        int(f), kernel_size=(3, 3), strides=(1, 1),
        padding='same',
        kernel_quantizer='quantized_bits(6,0,alpha=1)',
        bias_quantizer='quantized_bits(6,0,alpha=1)',
        kernel_initializer='lecun_uniform',
        kernel_regularizer=l1(0.0001),
        use_bias=True,
        name='fused_convbn_{}'.format(i)
    )(x)
    x = QActivation('quantized_relu(6)', name='conv_act_%i' % i)(x)
    x = MaxPooling2D(pool_size=(2, 2), name='pool_{}'.format(i))(x)


x = Flatten(name='flatten')(x)


x = QDense(
    32,
    kernel_quantizer='quantized_bits(6,0,alpha=1)',
    kernel_initializer='lecun_uniform',
    kernel_regularizer=l1(0.0001),
    name='dense_0' ,
    use_bias=False
)(x)
x = BatchNormalization(name='bn_dense_{}'.format(i))(x)
x = QActivation('quantized_relu(6)', name='dense_act_0')(x)

x     = Dense(int(n_classes), name='output_dense')(x)
x_out = Activation('softmax', name='output_softmax')(x)

qmodel = Model(inputs=[x_in], outputs=[x_out], name='qkeras')

qmodel.summary()
# Out:
# Input shape: (60000, 8, 8, 1)
# Model: "qkeras"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  img_input (InputLayer)      [(None, 8, 8, 1)]         0
#
#  fused_convbn_0 (QConv2DBat  (None, 8, 8, 4)           57
#  chnorm)
#
#  conv_act_0 (QActivation)    (None, 8, 8, 4)           0
#
#  pool_0 (MaxPooling2D)       (None, 4, 4, 4)           0
#
#  fused_convbn_1 (QConv2DBat  (None, 4, 4, 8)           329
#  chnorm)
#
#  conv_act_1 (QActivation)    (None, 4, 4, 8)           0
#
#  pool_1 (MaxPooling2D)       (None, 2, 2, 8)           0
#
#  flatten (Flatten)           (None, 32)                0
#
#  dense_0 (QDense)            (None, 32)                1024
#
#  bn_dense_1 (BatchNormaliza  (None, 32)                128
#  tion)
#
#  dense_act_0 (QActivation)   (None, 32)                0
#
#  output_dense (Dense)        (None, 10)                330
#
# ...

# %%
for layer in qmodel.layers:
    if layer.__class__.__name__ in ['Conv2D', 'Dense']:
        w = layer.get_weights()[0]
        layersize = np.prod(w.shape)
        print("{}: {}".format(layer.name, layersize))  # 0 = weights, 1 = biases
        if layersize > 4096:  # assuming that shape[0] is batch, i.e., 'None'
            print("Layer {} is too large ({}), are you sure you want to train?".format(layer.name, layersize))
# Out:
# output_dense: 320

# %%
print("=== QKeras Modell — Layer-Größen ===")
for layer in qmodel.layers:
    if layer.__class__.__name__ in ['QConv2DBatchnorm', 'QDense', 'Conv2D', 'Dense']:
        w = layer.get_weights()[0]
        size = np.prod(w.shape)
        flag = ' ← ZU GROSS (Strategy=Resource)' if size > 4096 else ' ✓'
        print(f'{layer.name:30s}: {size:>8d}{flag}')
# Out:
# === QKeras Modell — Layer-Größen ===
# fused_convbn_0                :       36 ✓
# fused_convbn_1                :      288 ✓
# dense_0                       :     1024 ✓
# output_dense                  :      320 ✓

# %% [markdown]
# ## 9. hls4ml-Konvertierung
#
# **Fixes gegenüber Standard:**
# - `backend='Vivado'` + `part='xc7z020clg400-1'` direkt (kein `board='pynq-z2'` — Board-Definition fehlt in Vivado 2019.2)
# - `ReuseFactor=576` für Dense (= Flatten-Output-Größe)
# - QKeras-Modell: keine manuelle ap_fixed-Konfiguration nötig (hls4ml liest 6-bit-Annotationen automatisch)

# %%
# !vivado -version
# Out:
# Vivado v2019.2 (64-bit)
# SW Build 2708876 on Wed Nov  6 21:39:14 MST 2019
# IP Build 2700528 on Thu Nov  7 00:09:20 MST 2019
# Copyright 1986-2019 Xilinx, Inc. All Rights Reserved.

# %%
import tensorflow as tf
import numpy as np
import tensorflow_model_optimization as tfmot
from tensorflow_model_optimization.sparsity import keras as sparsity
from tensorflow_model_optimization.python.core.sparsity.keras import pruning_callbacks
from tensorflow_model_optimization.sparsity.keras import strip_pruning

# 1. Chargement et conversion MNIST (Résolution 8x8 parfaite pour hls4ml)
mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = tf.image.resize(x_train[..., np.newaxis], [8, 8]).numpy() / 255.0
x_test  = tf.image.resize(x_test[..., np.newaxis],  [8, 8]).numpy() / 255.0

# NSTEPS doit être défini selon la taille de votre batch (ex: len(x_train) // batch_size)
# S'il n'est pas défini plus haut, vous pouvez ajouter une valeur par défaut ici, ex: NSTEPS = 100

# ── Pruning-Funktion ──────────────────────────────────────────────────────────
#1. Définition des hyperparamètres d'entraînement
BATCH_SIZE = 64
EPOCHS = 30

# 2. Calcul automatique du nombre de steps par époque
# (len(x_train) * 0.9) car vous utilisez un validation_split=0.1 (donc 90% des données vont à l'entraînement)
NSTEPS = int(np.ceil((len(x_train) * 0.9) / BATCH_SIZE))
print(f"Nombre de steps par époque : {NSTEPS}")

# ── Pruning-Funktion ──────────────────────────────────────────────────────────
def pruneFunction(layer):
    pruning_params = {'pruning_schedule': sparsity.PolynomialDecay(
        initial_sparsity=0.0, final_sparsity=0.50,
        begin_step=NSTEPS * 2,       # Commence à l'époque 2
        end_step=NSTEPS * 10,       # Finit à l'époque 10
        frequency=NSTEPS)}          # Met à jour les masques à chaque époque
    
    if isinstance(layer, tf.keras.layers.Conv2D):
        return tfmot.sparsity.keras.prune_low_magnitude(layer, **pruning_params)
    if isinstance(layer, tf.keras.layers.Dense) and layer.name != 'output_dense':
        return tfmot.sparsity.keras.prune_low_magnitude(layer, **pruning_params)
    return layer
qmodel_pruned = tf.keras.models.clone_model(qmodel, clone_function=pruneFunction)

# Transfert chirurgical des poids du modèle QKeras d'origine
for layer in qmodel.layers:
    try:
        tgt  = qmodel_pruned.get_layer(layer.name)
        ow   = layer.get_weights()
        tw   = tgt.get_weights()
        if ow and len(tw) >= len(ow):
            nw = list(tw)
            for i, w in enumerate(ow): nw[i] = w
            tgt.set_weights(nw)
    except: pass

# ── Configuration de l'entraînement ───────────────────────────────────────────
qmodel_pruned.compile(
    optimizer=tf.keras.optimizers.Adam(3e-4),
    loss='sparse_categorical_crossentropy',  
    metrics=['accuracy']
)

# Configuration stricte des Callbacks obligatoires
callbacks = [
    tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=10, restore_best_weights=True),
    tf.keras.callbacks.ModelCheckpoint('qmodel_pruned_best.h5', monitor='val_accuracy', save_best_only=True),
    tfmot.sparsity.keras.UpdatePruningStep() # Maintient les masques de pruning actifs
]

# ── Lancement unique du Training ──────────────────────────────────────────────
history = qmodel_pruned.fit(
    x_train, 
    y_train, 
    epochs=30, 
    batch_size=64, 
    validation_split=0.1,
    callbacks=callbacks # Correctement appliqué ici
)

# [CORRECTION] La deuxième ligne .fit() brute a été supprimée pour éviter l'erreur d'assertion.
# Out:
# Nombre de steps par époque : 844
# Epoch 1/30
# 844/844 [==============================] - 4s 3ms/step - loss: 1.8364 - accuracy: 0.4041 - val_loss: 1.3639 - val_accuracy: 0.6023
# Epoch 2/30
#  57/844 [=>............................] - ETA: 2s - loss: 1.3875 - accuracy: 0.5869
# /home/yvan/miniconda3/envs/hls4ml-tutorial/lib/python3.10/site-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# /home/yvan/miniconda3/envs/hls4ml-tutorial/lib/python3.10/site-packages/keras/src/constraints.py:365: UserWarning: The `keras.constraints.serialize()` API should only be used for objects of type `keras.constraints.Constraint`. Found an instance of type <class 'qkeras.quantizers.quantized_bits'>, which may lead to improper serialization.
#   warnings.warn(
# ...

# %%
qmodel_pruned   = tf.keras.models.load_model('qmodel_pruned_best.h5', custom_objects=co)
qmodel_stripped = strip_pruning(qmodel_pruned)
qmodel_stripped.save('qmodel_stripped.h5')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
 def divisors(n):
    """Tous les diviseurs de n, triés croissant."""
    divs = set()
    i = 1
    while i * i <= n:
        if n % i == 0:
            divs.add(i); divs.add(n // i)
        i += 1
    return sorted(divs)

# 
def make_hls_config(model, default_precision='ap_fixed<16,5>'):
    # 1. On repart sur une base saine en 16 bits pour sécuriser l'accuracy
    cfg = hls4ml.utils.config_from_keras_model(
        model, granularity='name', default_precision=default_precision)
    
    cfg['Model']['Strategy'] = 'Resource'
    #cfg['Model']['ReuseFactor'] = 999999   # Fallback max
    # Force Vivado à utiliser des LUTs (Distributed RAM) pour les petits tableaux et FIFOs
    cfg['Model']['MemoryStorage'] = 'distributed'
    #cfg['Model']['Precision']   = 'ap_fixed<12,4>'
    cfg['Model']['ReuseFactor'] = 16
    #cfg['Model']['Strategy'] = 'Resource'

    #grau Zone 
    #conv layer und dense_0: 2**1 ist max--> 1 +1 --> ap_fixed<8,3>--> [-4;3,96875] 
    #hier z.b wurde ap_fixed<8,2> nicht reichend MAx=1,984375<2 sieh graph
    cfg['LayerName']['fused_convbn_0']['Precision']['weight']  = 'ap_fixed<8,3>'
    cfg['LayerName']['fused_convbn_0']['Precision']['bias']    = 'ap_fixed<8,3>'
    cfg['LayerName']['fused_convbn_0']['ReuseFactor'] = 9
    
    cfg['LayerName']['fused_convbn_1']['Precision']['weight']  = 'ap_fixed<8,3>'
    cfg['LayerName']['fused_convbn_1']['Precision']['bias']    = 'ap_fixed<8,3>'
    cfg['LayerName']['fused_convbn_1']['ReuseFactor'] = 9
    
    cfg['LayerName']['dense_0']['Precision']['weight'] = 'ap_fixed<8,3>'
    cfg['LayerName']['dense_0']['Precision']['bias']   = 'ap_fixed<8,3>'
    cfg['LayerName']['dense_0']['ReuseFactor'] = 9


    #bn_dense_1 : 2*4 ist das max-->4 + 1 = I = 5---> ap_fixed<12,5>
    cfg['LayerName']['bn_dense_1']['Precision']['weight'] = 'ap_fixed<8,5>'
    cfg['LayerName']['bn_dense_1']['Precision']['bias']   = 'ap_fixed<8,5>'
    
    cfg['LayerName']['output_dense']['ReuseFactor'] = 16
    cfg['LayerName']['output_dense']['Precision']['result'] = 'fixed<16,5,RND,SAT>'

            
    return cfg





# ── QAT + Pruning ─────────────────────────────────────────────────────────────
import shutil
OUT = 'model_personDetection/hls4ml_prj_qat'
shutil.rmtree(OUT, ignore_errors=True)

cfg_q = make_hls_config(qmodel_stripped)
#cfg_q['Flows'] = ['vivado:fifo_depth_optimization']
# Force une profondeur FIFO réduite pour tout le modèle
#cfg_q['Model']['FIFO_depth'] = 256   # au lieu de 2304 par défaut

hls_model_q = hls4ml.converters.convert_from_keras_model(
    qmodel_stripped, hls_config=cfg_q, output_dir=OUT,
    backend='Vitis', part='xc7z020clg400-1', io_type='io_stream'
)

#

hls_model_q.compile()

out_q = hls_model_q.predict(x_test[:100])
print(f'std={out_q[:,1].std():.4f}  kollaps={out_q[:,1].std()<1e-6}')

import numpy as np
out  = hls_model_q.predict(x_test[:500])
acc  = np.mean(np.argmax(out,axis=1) == y_test[:500])
print(f'Emu acc avec ap_fixed<12,4>: {acc*100:.1f}%')   # doit rester proche de 67%


print('path:', os.path.abspath(OUT))
# Out:
# Interpreting Model
# Topology:
# Layer name: img_input, layer type: InputLayer, input shapes: [[None, 8, 8, 1]], output shape: [None, 8, 8, 1]
# Layer name: fused_convbn_0, layer type: QConv2DBatchnorm, input shapes: [[None, 8, 8, 1]], output shape: [None, 8, 8, 4]
# Layer name: conv_act_0, layer type: Activation, input shapes: [[None, 8, 8, 4]], output shape: [None, 8, 8, 4]
# Layer name: pool_0, layer type: MaxPooling2D, input shapes: [[None, 8, 8, 4]], output shape: [None, 4, 4, 4]
# Layer name: fused_convbn_1, layer type: QConv2DBatchnorm, input shapes: [[None, 4, 4, 4]], output shape: [None, 4, 4, 8]
# Layer name: conv_act_1, layer type: Activation, input shapes: [[None, 4, 4, 8]], output shape: [None, 4, 4, 8]
# Layer name: pool_1, layer type: MaxPooling2D, input shapes: [[None, 4, 4, 8]], output shape: [None, 2, 2, 8]
# Layer name: flatten, layer type: Reshape, input shapes: [[None, 2, 2, 8]], output shape: [None, 32]
# ...

# %%
import numpy as np

# 1. Accuracy du Keras pur (AVANT hls4ml)
keras_out = qmodel_stripped.predict(x_test[:500])
keras_acc = np.mean(np.argmax(keras_out, axis=1) == y_test[:500])
print(f'Keras pur        : {keras_acc*100:.1f}%')

# 2. Distribution des labels (le bug de classes que tu connais)
print(f'Distribution y_val: {np.bincount(y_test[:500])}')   # attendu ~[100,100]

# 3. Accord Keras vs HLS sur les mêmes images
k = np.argmax(qmodel_stripped.predict(x_test[:500]), axis=1)
h = np.argmax(hls_model_q.predict(x_test[:500]), axis=1)
print(f'Accord Keras/HLS : {np.mean(k==h)*100:.0f}%')
# Out:
# 16/16 [==============================] - 0s 848us/step
# Keras pur        : 82.6%
# Distribution y_val: [42 67 55 45 55 50 43 49 40 54]
# 16/16 [==============================] - 0s 830us/step
# Accord Keras/HLS : 98%

# %%
hls4ml.utils.plot_model(hls_model_q, show_shapes=True, show_precision=True, to_file=None)

# %%
import matplotlib.pyplot as plt
from hls4ml.model.profiling import numerical
# %matplotlib inline

numerical(model=qmodel_stripped, hls_model=hls_model_q)

#conv layer und dense_0: 2**1 ist max--> 1 +1 --> ap_fixed<8,3>--> [-4;3,96875] hier z.b wurde ap_fixed<8,2> nicht reichend MAx=1,984375<2 sieh graph
#bn_dense_1 : 2**4 ist das max-->4 + 1 = I = 5---> ap_fixed<12,5>--> [-2^(5-1);+2^(5-1)-2^(-12+5)]-->Max;Min=[-16;+15,9921875]
# Out:
# /home/yvan/miniconda3/envs/hls4ml-tutorial/lib/python3.10/site-packages/keras/src/constraints.py:365: UserWarning: The `keras.constraints.serialize()` API should only be used for objects of type `keras.constraints.Constraint`. Found an instance of type <class 'qkeras.quantizers.quantized_bits'>, which may lead to improper serialization.
#   warnings.warn(
# Interpreting Model
# Topology:
# Layer name: img_input, layer type: InputLayer, input shapes: [[None, 8, 8, 1]], output shape: [None, 8, 8, 1]
# Layer name: fused_convbn_0, layer type: QConv2DBatchnorm, input shapes: [[None, 8, 8, 1]], output shape: [None, 8, 8, 4]
# Layer name: conv_act_0, layer type: Activation, input shapes: [[None, 8, 8, 4]], output shape: [None, 8, 8, 4]
# Layer name: pool_0, layer type: MaxPooling2D, input shapes: [[None, 8, 8, 4]], output shape: [None, 4, 4, 4]
# Layer name: fused_convbn_1, layer type: QConv2DBatchnorm, input shapes: [[None, 4, 4, 4]], output shape: [None, 4, 4, 8]
# ...

# %% [markdown]
# ## hls4ml.utils.plot_model(hls_model_q, show_shapes=True, show_precision=True,
#                          to_file='model_hls4ml.png')

# %%
import pprint
pprint.pprint(hls4ml.backends.get_backend('VivadoAccelerator').create_initial_config('fpga', part='xc7z020clg400-1',  clock_period=5, io_type='io_stream'))
# Out:
# {'AcceleratorConfig': {'Board': 'fpga',
#                        'Driver': 'python',
#                        'Interface': 'axi_stream',
#                        'Precision': {'Input': 'float', 'Output': 'float'}},
#  'ClockPeriod': 5,
#  'ClockUncertainty': '12.5%',
#  'HLSConfig': {},
#  'IOType': 'io_stream',
#  'Part': 'xc7z020clg400-1',
#  'WriterConfig': {'Namespace': None,
#                   'WriteTar': False,
#                   'WriteWeightsTxt': True}}

# %%
import numpy as np

# 1. Accuracy du Keras pur (AVANT hls4ml)
keras_out = qmodel_stripped.predict(x_test[:500])
keras_acc = np.mean(np.argmax(keras_out, axis=1) == y_test[:500])
print(f'Keras pur        : {keras_acc*100:.1f}%')

# 2. Distribution des labels (le bug de classes que tu connais)
print(f'Distribution y_val: {np.bincount(y_test[:500])}')   # attendu ~[100,100]

# 3. Accord Keras vs HLS sur les mêmes images
k = np.argmax(qmodel_stripped.predict(x_test[:500]), axis=1)
h = np.argmax(hls_model_q.predict(x_test[:500]), axis=1)
print(f'Accord Keras/HLS : {np.mean(k==h)*100:.0f}%')
# Out:
# 16/16 [==============================] - 0s 939us/step
# Keras pur        : 82.6%
# Distribution y_val: [42 67 55 45 55 50 43 49 40 54]
# 16/16 [==============================] - 0s 1ms/step
# Accord Keras/HLS : 98%

# %%
# ── Lancement Automatique de la Synthèse ──────────────────────────────────────
print("\n[INFO] Lancement de la synthèse Vivado HLS (export IP inclus)...")
# Lance la C-Synthèse complète et exporte l'IP Block (.zip) pour Vivado Vivado
hls_model_q.build(reset=True, csim=False, synth=True, vsynth=True, export=True)
#hls_model_q.build(csim=False,cosim=False, synth=True, export=True)
# Out:
# [INFO] Lancement de la synthèse Vivado HLS (export IP inclus)...
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[40], line 4
#       2 print("\n[INFO] Lancement de la synthèse Vivado HLS (export IP inclus)...")
#       3 # Lance la C-Synthèse complète et exporte l'IP Block (.zip) pour Vivado Vivado
# ----> 4 hls_model_q.build(reset=True, csim=False, synth=True, vsynth=True, export=True)
#       5 #hls_model_q.build(csim=False,cosim=False, synth=True, export=True)
#
# File ~/miniconda3/envs/hls4ml-tutorial/lib/python3.10/site-packages/hls4ml/model/graph.py:896, in ModelGraph.build(self, **kwargs)
#     892 if not os.path.exists(self.config.get_output_dir()):
#     893     # Assume the project wasn't written before
#     894     self.write()
# --> 896 return self.config.backend.build(self, **kwargs)
#
# ...

# %% [markdown]
# ## 10. CPU-Emulation und Genauigkeitsvergleich

# %%
#y_hls_b  = hls_model.predict(X_val);   y_pred_hls_b = np.argmax(y_hls_b, axis=1)
y_hls_q  = hls_model_q.predict(X_val); y_pred_hls_q = np.argmax(y_hls_q, axis=1)
#acc_hls_b = np.mean(y_pred_hls_b == y_val)
acc_hls_q = np.mean(y_pred_hls_q == y_val)

np.save('y_true.npy', y_val)
#np.save('y_hls_pruned.npy', y_hls_b)
np.save('y_hls_qat.npy',    y_hls_q)

print('=' * 68)
print('  VOLLSTÄNDIGER GENAUIGKEITSVERGLEICH')
print('=' * 68)
#print(f'  Baseline (Keras float32)             : {acc_base*100:.2f} %')
#print(f'  Baseline + Pruning (Keras)            : {acc_pruned*100:.2f} %')
print(f'  QAT 6-bit + Pruning (QKeras)          : {acc_q*100:.2f} %')
#print(f'  Baseline + Pruning (hls4ml CPU-Emu)   : {acc_hls_b*100:.2f} %')
print(f'  QAT + Pruning      (hls4ml CPU-Emu)   : {acc_hls_q*100:.2f} %')
print(f'  Wang et al. [FPL 2019] ZCU102 8-bit   :  72.98 %')
print('=' * 68)

klassen = ['non_person', 'person']
fig, axes = plt.subplots(1, 2, figsize=(12, 4))
for ax, yp, t in zip(axes, [ y_pred_hls_q], #[y_pred_hls_b, y_pred_hls_q],
                     ['QAT+Pruning hls4ml']):        #['Baseline+Pruning hls4ml', 'QAT+Pruning hls4ml']):
    cm = confusion_matrix(y_val, yp, labels=[0,1])
    ax.imshow(cm, cmap='Blues')
    ax.set_xticks([0,1]); ax.set_yticks([0,1])
    ax.set_xticklabels(klassen); ax.set_yticklabels(klassen)
    ax.set_xlabel('Vorhergesagt'); ax.set_ylabel('Wahr'); ax.set_title(t)
    for i in range(2):
        for j in range(2): ax.text(j, i, str(cm[i,j]), ha='center', va='center', fontsize=14)
plt.tight_layout(); plt.savefig('konfusionsmatrizen.png', dpi=120); plt.show()
print(classification_report(y_val, y_pred_hls_q, target_names=klassen, zero_division=0))

# %% [markdown]
# ## 11. Plattformvergleich: STM32 vs. FPGA
#
# **Referenz Bachelorarbeit:** MobileNetV2 TFLite-int8 auf STM32 → **303 ms** (Abb. 51 & 52)
# [Betriebliche Praxis — Simo Gueno](https://github.com/yvsim001/PYNQ_HDMI/blob/main/docs%2FBetriebliche%20Praxis-Herr%20SIMO%20GUENO.pdf)

# %% [markdown]
# STM32_MS = 303.0; KLASSEN = {0:'Keine Person', 1:'Person'}; N_RUNS = 10
# pidx = np.where(y_val==1)[0]; nidx = np.where(y_val==0)[0]
#
# results = []
# fig, axes = plt.subplots(2, 2, figsize=(13, 8))
# fig.suptitle('STM32 MCU vs. FPGA (Baseline+Pruned & QAT+Pruned)', fontsize=12, fontweight='bold')
#
# for col, (lbl, idx) in enumerate({'Person':pidx[0],'Keine Person':nidx[0]}.items()):
#     img = X_val[idx]; true = KLASSEN[y_val[idx]]
#     for row, (hm, name) in enumerate([(hls_model,'Baseline+Pruned'),
#                                        (hls_model_q,'QAT+Pruned')]):
#         t0 = time.perf_counter()
#         for _ in range(N_RUNS): p = hm.predict(img[np.newaxis])[0]
#         t_ms = (time.perf_counter()-t0)/N_RUNS*1000
#         speedup = STM32_MS/t_ms
#         results.append({'model':name,'label':lbl,'true':true,
#                          'pred':KLASSEN[int(np.argmax(p))],'t_ms':t_ms,'speedup':speedup})
#         ax = axes[row][col]
#         ax.imshow(img); ax.axis('off')
#         ax.set_title(f'{name} | {lbl}', fontsize=9)
#         info = (f'Pred: {KLASSEN[int(np.argmax(p))]} ({float(np.max(p))*100:.1f}%)  {t_ms:.1f} ms\n'
#                 f'STM32: 303 ms | Beschl.: {speedup:.0f}x')
#         ax.text(0,-5,info,transform=ax.transData,fontsize=8.5,va='top',
#                 bbox=dict(boxstyle='round',facecolor='#eef4ff',alpha=0.9))
#
# plt.tight_layout(); plt.savefig('plattformvergleich.png',dpi=150,bbox_inches='tight')
# plt.show()
#
# print('\n' + '='*70)
# print(f'{"Kriterium":32s} {"STM32 (BA)":>14s} {"Pruned":>10s} {"QAT+Pruned":>12s}')
# print('-'*70)
# for r0, r1 in [(results[0],results[1])]:
#     rows = [
#         ('Modell',       'MobileNetV2',  'Custom-CNN', 'Custom-CNN'),
#         ('Quantisierung','TFLite int8',  'float32',    'QKeras 6-bit'),
#         ('Pruning',      'Nein',         '50%',        '50%'),
#         ('Genauigkeit',  '~86%',         f'{acc_hls_b*100:.1f}%', f'{acc_hls_q*100:.1f}%'),
#         ('Inferenz',     '303 ms',       f"{r0['t_ms']:.1f} ms", f"{r1['t_ms']:.1f} ms"),
#         ('Beschleun.',   '1x',           f"{r0['speedup']:.0f}x", f"{r1['speedup']:.0f}x"),
#     ]
#     for row in rows:
#         print(f'{row[0]:32s} {row[1]:>14s} {row[2]:>10s} {row[3]:>12s}')
# print('='*70)

# %%
STM32_MS = 303.0; KLASSEN = {0:'Keine Person', 1:'Person'}; N_RUNS = 10
pidx = np.where(y_val==1)[0]; nidx = np.where(y_val==0)[0]

results = []
fig, axes = plt.subplots(2, 2, figsize=(13, 8))
fig.suptitle('STM32 MCU vs. FPGA (QAT+Pruned)', fontsize=12, fontweight='bold')

for col, (lbl, idx) in enumerate({'Person':pidx[0],'Keine Person':nidx[0]}.items()):
    img = X_val[idx]; true = KLASSEN[y_val[idx]]
    for row, (hm, name) in enumerate([hls_model_q,'QAT+Pruned')]):
        t0 = time.perf_counter()
        for _ in range(N_RUNS): p = hm.predict(img[np.newaxis])[0]
        t_ms = (time.perf_counter()-t0)/N_RUNS*1000
        speedup = STM32_MS/t_ms
        results.append({'model':name,'label':lbl,'true':true,
                         'pred':KLASSEN[int(np.argmax(p))],'t_ms':t_ms,'speedup':speedup})
        ax = axes[row][col]
        ax.imshow(img); ax.axis('off')
        ax.set_title(f'{name} | {lbl}', fontsize=9)
        info = (f'Pred: {KLASSEN[int(np.argmax(p))]} ({float(np.max(p))*100:.1f}%)  {t_ms:.1f} ms\n'
                f'STM32: 303 ms | Beschl.: {speedup:.0f}x')
        ax.text(0,-5,info,transform=ax.transData,fontsize=8.5,va='top',
                bbox=dict(boxstyle='round',facecolor='#eef4ff',alpha=0.9))

plt.tight_layout(); plt.savefig('plattformvergleich.png',dpi=150,bbox_inches='tight')
plt.show()

print('\n' + '='*70)
print(f'{"Kriterium":32s} {"STM32 (BA)":>14s} {"QAT+Pruned":>12s}')
print('-'*70)

for r0, r1 in [(results[0],results[1])]:
    rows = [
        ('Modell',       'MobileNetV2', 'Custom-CNN'),
        ('Quantisierung','TFLite int8',  'QKeras 6-bit'),
        ('Pruning',      'Nein',         '50%'),
        ('Genauigkeit',  '~86%',         f'{acc_hls_q*100:.1f}%'),
        ('Inferenz',     '303 ms',       f"{r1['t_ms']:.1f} ms"),
        ('Beschleun.',   '1x',           f"{r1['speedup']:.0f}x"),
    ]
    for row in rows:
        print(f'{row[0]:32s} {row[1]:>14s} {row[2]:>10s} {row[3]:>12s}')
print('='*70)

# %% [markdown]
# ## 12. Synthesebericht — Latenz und Ressourcen

# %%
def get_hls_report(d):
    rpt = Path(d)/'myproject_prj/solution1/syn/report/myproject_csynth.rpt'
    data = {}
    if not rpt.is_file(): print(f'Bericht nicht gefunden: {rpt}'); return data
    for i, line in enumerate(rpt.read_text().splitlines()):
        if 'Latency (cycles)' in line:
            p = rpt.read_text().splitlines()[i+3].split('|')
            if len(p)>=7:
                try:
                    data['takte']  = int(p[2].strip())
                    data['us']     = round(int(p[2].strip())*10/1000, 3)
                    data['II']     = int(p[6].strip())
                    data['fps']    = round(100e6/int(p[6].strip()))
                except: pass
            break
    return data

def get_impl_report(d):
    rpt = Path(d)/('myproject_vivado_accelerator/project_1.runs/impl_1/'
                    'design_1_wrapper_utilization_placed.rpt')
    if not rpt.is_file(): return {}
    c = rpt.read_text()
    return {k: int(re.search(p,c).group(1)) for k,p in [
        ('LUT',r'Slice LUTs\*?\s*\|\s*(\d+)'),
        ('FF', r'Slice Registers\s*\|\s*(\d+)'),
        ('BRAM',r'Block RAM Tile\s*\|\s*(\d+)'),
        ('DSP',r'DSPs\s*\|\s*(\d+)')] if re.search(p,c)}

AV = {'LUT':53200,'FF':106400,'BRAM':280,'DSP':220}

for name, d in [('QAT+Pruned',    'model_personDetection/hls4ml_prj_qat')]: #('Baseline+Pruned','model_personDetection/hls4ml_prj_pruned'),
    h = get_hls_report(d); imp = get_impl_report(d)
    src = imp if imp else h
    print(f'\n=== {name} ===')
    if h.get('fps'):
        print(f'  Latenz  : {h["takte"]} Takte = {h["us"]} us')
        print(f'  Durchsatz: {h["fps"]:,} Inf/s  ({h["fps"]/3.3:.0f}x vs STM32)')
    for res in ['LUT','FF','BRAM','DSP']:
        v = src.get(res)
        if v: print(f'  {res:5s}: {v:>6d}/{AV[res]}  ({v/AV[res]*100:.1f}%)')

print('Berichtsfunktionen bereit.')

# %% [markdown]
# ## 13. Synthese und Bitstream-Erzeugung
#
# > Dauer: ca. 30–60 Minuten pro Modell.
# > Fortschritt: `tail -f model_personDetection/hls4ml_prj_qat/vivado_hls.log`
#
# **Bekannte Warnings (nicht-blockierend):**
# - `HLS 214-113` / `HLS 214-114` — Dataflow-Variablen in io_stream, normal für hls4ml
# - `HLS 200-471` — Dataflow form checks, nicht-blockierend

# %% [markdown]
# #print('=== Synthese: Baseline+Pruning ===')
# #hls_model.build(csim=False, export=True, bitfile=True)
#
# print('\n=== Synthese: QAT+Pruning ===')
# hls_model_q.build(csim=False, export=True, bitfile=True)

# %%
hls_model_q.build(csim=False)

# %%
# Post-Synthese-Berichte
for name, d in [('QAT+Pruned',   'model_personDetection/hls4ml_prj_qat')]:         #('Baseline+Pruned','model_personDetection/hls4ml_prj_pruned'),
    h = get_hls_report(d); imp = get_impl_report(d)
    src = imp if imp else h
    print(f'\n=== {name} (Post-Synthese) ===')
    if h.get('fps'): print(f'  {h["fps"]:,} Inf/s  Beschl. {h["fps"]/3.3:.0f}x vs STM32')
    for res in ['LUT','FF','BRAM','DSP']:
        v = src.get(res)
        if v: print(f'  {res}: {v}/{AV[res]} ({v/AV[res]*100:.1f}%)')

# %% [markdown]
# ## 14. Deployment-Vorbereitung
#
# Das **QAT+Pruning-Modell** wird gepackt (bessere Ressourceneffizienz).
# **Verbindung:** USB Micro-B → Port J14 · IP `192.168.2.99 >> 10.3.37.177` · PW `xilinx`

# %%
SRC = 'model_personDetection/hls4ml_prj_qat'
PKG = SRC + '/package'
os.makedirs(PKG, exist_ok=True)

copies = [
    (SRC+'/myproject_vivado_accelerator/project_1.runs/impl_1/design_1_wrapper.bit', PKG+'/hls4ml_nn.bit'),
    (SRC+'/myproject_vivado_accelerator/project_1.srcs/sources_1/bd/'
          'design_1/hw_handoff/design_1.hwh', PKG+'/hls4ml_nn.hwh'),
    (SRC+'/axi_stream_driver.py', PKG+'/axi_stream_driver.py'),
]
for src, dst in copies:
    if Path(src).is_file(): shutil.copy2(src, dst); print(f'Kopiert: {Path(src).name}')
    else: print(f'Nicht gefunden (erst nach Synthese): {Path(src).name}')

for f in ['y_true.npy','y_hls_pruned.npy','y_hls_qat.npy',
           'qmodel_stripped.h5','konfusionsmatrizen.png','plattformvergleich.png']:
    if Path(f).is_file(): shutil.copy2(f, PKG+'/'+f); print(f'Kopiert: {f}')

subprocess.run(['tar','-czvf',SRC+'/package.tar.gz','-C',PKG,'.'], check=True)
print('\nPaket: '+SRC+'/package.tar.gz')

# %%
# sudo ip addr add 192.168.2.1/24 dev usb0 && sudo ip link set usb0 up
# !scp model_personDetection/hls4ml_prj_qat/package.tar.gz \
     xilinx@192.168.2.99:~/jupyter_notebooks/
print('Weiter auf PYNQ-Z1 (http://192.168.2.99): tar xvzf package.tar.gz')
